# %%
import os 
import psycopg2
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import seaborn as sns
# %matplotlib inline

# %%
##Load variables 
from dotenv import load_dotenv, find_dotenv
load_dotenv(find_dotenv('fire_var.env'))
# Out:
# True

# %%
# connect to postgres

try:
    conn = psycopg2.connect(database=os.environ.get("erdatabase"), user=os.environ.get("eruser"), 
                            password = os.environ.get("erpassword"), 
                            host=os.environ.get("erhost"), 
                            port=os.environ.get('port'))
    
except psycopg2.Error as e:
    print("I am unable to connect to the database")
    print(e)
    print(e.pgcode)
    print(e.pgerror)
    print(traceback.format_exc())

# %%
def pgquery(QUERY): 
    '''
    takes SQL query string, opens a cursor, and executes query in psql
    '''
    
    cur = conn.cursor()
    
    try:
        print("SQL QUERY = "+QUERY)
        cur.execute("SET statement_timeout = 0")
        cur.execute(QUERY)
        # Extract the column names and insert them in header
        col_names = []
        for elt in cur.description:
            col_names.append(elt[0])    
    
        D = cur.fetchall() #convert query result to list
        #pprint(D)
        #conn.close()
        # Create the dataframe, passing in the list of col_names extracted from the description
        return pd.DataFrame(D, columns=col_names)

    except Exception as e:
        print(e.pgerror)

# %%
## Since we only have one row in the incident table, there is not much data to pull from there.
## Let's try to pull everything about the responders.

##Pull data from the EC2 instance, extract inctime, station, and agency info
def getTimeDataset1(timedesc_dict):
    RESPONSE_TIME_QUERY='''
                        
                        SELECT  I.incident_id, R.responderunit_id,
                                T.timedesc_id, S.description as Station, A.description as Agency,
                                T.realtime
                        FROM incident as I
                        INNER JOIN inctimes as T
                                ON I.incident_id = T.incident_id
                        INNER JOIN responder as R
                                ON ( I.incident_id = R.incident_id AND T.responder_id = R.responder_id)
                        INNER JOIN responderunit as RU
                                ON R.responderunit_id = RU.responderunit_id
                        LEFT JOIN station as S
                                ON RU.station_id= S.station_id
                        LEFT JOIN agency as A
                                ON RU.agency_id = A.agency_id
                        WHERE T.timedesc_id IN ??TIMEDESC_IDS??
                                AND T.responder_id IS NOT NULL
                                AND I.incident_id = 1281359;
                        '''
    
    # add the timedesc_ids that we want to the query
    timedesc_ids = str(tuple(timedesc_dict.keys())).replace("'", "")
    RESPONSE_TIME_QUERY = RESPONSE_TIME_QUERY.replace("??TIMEDESC_IDS??", str(timedesc_ids))
    
    # execute the query: **this takes a pretty long time**
    df = pgquery(RESPONSE_TIME_QUERY)
    
   
    return df

# %%
d = {3: 'Dispatched', 5 : 'On Scene', 9: 'Depart Scene', 12: 'Clear'}
table = getTimeDataset1(d)
# Out:
# SQL QUERY =
#
#                         SELECT  I.incident_id, R.responderunit_id,
#                                 T.timedesc_id, S.description as Station, A.description as Agency,
#                                 T.realtime
#                         FROM incident as I
#                         INNER JOIN inctimes as T
#                                 ON I.incident_id = T.incident_id
#                         INNER JOIN responder as R
#                                 ON ( I.incident_id = R.incident_id AND T.responder_id = R.responder_id)
#                         INNER JOIN responderunit as RU
#                                 ON R.responderunit_id = RU.responderunit_id
#                         LEFT JOIN station as S
#                                 ON RU.station_id= S.station_id
#                         LEFT JOIN agency as A
#                                 ON RU.agency_id = A.agency_id
#                         WHERE T.timedesc_id IN (9, 3, 12, 5)
#                                 AND T.responder_id IS NOT NULL
#                                 AND I.incident_id = 1281359;

# %%
len(table)
# Out:
# 233

# %%
table.head(233)
# Out:
#      incident_id  responderunit_id  timedesc_id                 station  \
# 0        1281359                89            3  INVESTIGATOR/INSPECTOR
# 1        1281359                89            3  INVESTIGATOR/INSPECTOR
# 2        1281359                89            5  INVESTIGATOR/INSPECTOR
# 3        1281359                89            5  INVESTIGATOR/INSPECTOR
# 4        1281359                89           12  INVESTIGATOR/INSPECTOR
# 5        1281359                89           12  INVESTIGATOR/INSPECTOR
# 6        1281359                93            3  INVESTIGATOR/INSPECTOR
# 7        1281359                93            3  INVESTIGATOR/INSPECTOR
# 8        1281359                93            5  INVESTIGATOR/INSPECTOR
# 9        1281359                93            5  INVESTIGATOR/INSPECTOR
# 10       1281359                93           12  INVESTIGATOR/INSPECTOR
# 11       1281359                93           12  INVESTIGATOR/INSPECTOR
# 12       1281359                95            3                    None
# 13       1281359                95            3                    None
# 14       1281359                95            5                    None
# 15       1281359                95            5                    None
# 16       1281359                95           12                    None
# 17       1281359                96            3                    None
# 18       1281359                96            5                    None
# 19       1281359                96           12                    None
# 20       1281359               101            3                     PIO
# 21       1281359               101            5                     PIO
# 22       1281359               102            3                     PIO
# 23       1281359               102            5                     PIO
# 24       1281359               103            3                     PIO
# 25       1281359               103            5                     PIO
# 26       1281359               114            3                      01
# 27       1281359               114            5                      01
# 28       1281359               114           12                      01
# 29       1281359               116            3                      01
# ..           ...               ...          ...                     ...
# 203      1281359              1597            3                      24
# 204      1281359              1597            5                      24
# 205      1281359              1597           12                      24
# 206      1281359              1602            3                      05
# 207      1281359              1602            5                      05
# 208      1281359              1602           12                      05
# 209      1281359                45            3                      24
# 210      1281359                45            5                      24
# 211      1281359                45           12                      24
# 212      1281359                51            3                      26
# 213      1281359                51            5                      26
# 214      1281359                51           12                      26
# 215      1281359                52            3                      03
# 216      1281359                52            3                      03
# 217      1281359                52            5                      03
# 218      1281359                52            5                      03
# 219      1281359                52           12                      03
# 220      1281359                52           12                      03
# 221      1281359                56            3                      04
# 222      1281359                56            5                      04
# 223      1281359                56           12                      04
# 224      1281359                62            3                      05
# 225      1281359                62            5                      05
# 226      1281359                62           12                      05
# 227      1281359                64            3                      06
# 228      1281359                64            5                      06
# 229      1281359                64           12                      06
# 230      1281359                79            3                      09
# 231      1281359                79            5                      09
# 232      1281359                79           12                      09
#
#       agency            realtime
# 0       None 2016-10-19 10:05:14
# 1       None 2016-10-20 06:28:34
# 2       None 2016-10-19 12:56:38
# 3       None 2016-10-20 06:28:34
# 4       None 2016-10-19 22:07:44
# 5       None 2016-10-20 19:39:08
# 6       None 2016-10-19 09:48:54
# 7       None 2016-10-20 06:27:43
# 8       None 2016-10-19 09:48:57
# 9       None 2016-10-20 06:27:43
# 10      None 2016-10-19 18:15:53
# 11      None 2016-10-20 16:55:02
# 12   GRESHAM 2016-10-20 06:31:09
# 13   GRESHAM 2016-10-21 08:49:13
# 14   GRESHAM 2016-10-20 07:16:06
# 15   GRESHAM 2016-10-21 08:49:13
# 16   GRESHAM 2016-10-20 16:02:29
# 17   GRESHAM 2016-10-20 06:31:09
# 18   GRESHAM 2016-10-20 07:16:06
# 19   GRESHAM 2016-10-20 16:02:29
# 20      None 2016-10-19 09:39:33
# 21      None 2016-10-19 09:56:32
# 22      None 2016-10-19 11:05:10
# 23      None 2016-10-19 11:05:10
# 24      None 2016-10-19 11:05:14
# 25      None 2016-10-19 11:05:14
# 26      None 2016-10-19 10:17:11
# 27      None 2016-10-19 10:21:08
# 28      None 2016-10-19 12:06:03
# 29      None 2016-10-19 10:19:31
# ..       ...                 ...
# 203     None 2016-10-20 16:02:21
# 204     None 2016-10-20 16:04:12
# 205     None 2016-10-20 16:08:52
# 206     None 2016-10-19 09:39:33
# 207     None 2016-10-19 09:52:47
# 208     None 2016-10-19 21:56:28
# 209     None 2016-10-19 09:39:33
# 210     None 2016-10-19 09:43:49
# 211     None 2016-10-19 10:14:54
# 212     None 2016-10-19 10:12:45
# 213     None 2016-10-19 10:21:01
# 214     None 2016-10-19 14:42:58
# 215     None 2016-10-19 09:08:12
# 216     None 2016-10-21 10:14:37
# 217     None 2016-10-19 09:12:00
# 218     None 2016-10-21 10:19:50
# 219     None 2016-10-19 19:30:46
# 220     None 2016-10-21 14:55:48
# 221     None 2016-10-19 09:39:33
# 222     None 2016-10-19 09:43:43
# 223     None 2016-10-19 12:19:27
# 224     None 2016-10-19 09:44:11
# 225     None 2016-10-19 09:55:56
# 226     None 2016-10-19 19:58:53
# 227     None 2016-10-19 09:08:12
# 228     None 2016-10-19 09:15:44
# 229     None 2016-10-19 15:16:36
# 230     None 2016-10-19 10:19:39
# 231     None 2016-10-19 10:55:52
# 232     None 2016-10-19 15:17:29
#
# [233 rows x 6 columns]

# %% [markdown]
# ## It seems the records expand more than one day, so let's pull the data just for '2016-10-19'

# %%
##Pull data from the EC2 instance, extract inctime, station, and agency info

## on date '2016-10-19'

def getTimeDataset2(timedesc_dict):
    RESPONSE_TIME_QUERY='''
                        
                        SELECT  R.responderunit_id,
                                T.timedesc_id, S.description as Station, A.description as Agency,
                                RU.description as Responder,
                                T.realtime
                        FROM incident as I
                        INNER JOIN inctimes as T
                                ON I.incident_id = T.incident_id
                        INNER JOIN responder as R
                                ON ( I.incident_id = R.incident_id AND T.responder_id = R.responder_id)
                        INNER JOIN responderunit as RU
                                ON R.responderunit_id = RU.responderunit_id
                        LEFT JOIN station as S
                                ON RU.station_id= S.station_id
                        LEFT JOIN agency as A
                                ON RU.agency_id = A.agency_id
                        WHERE T.timedesc_id IN ??TIMEDESC_IDS??
                                AND T.responder_id IS NOT NULL
                                AND I.incident_id = 1281359
                                AND CAST(T.realtime AS DATE) = date '2016-10-19'
                        ORDER BY T.realtime
                                ASC;
                        '''
    
    # add the timedesc_ids that we want to the query
    timedesc_ids = str(tuple(timedesc_dict.keys())).replace("'", "")
    RESPONSE_TIME_QUERY = RESPONSE_TIME_QUERY.replace("??TIMEDESC_IDS??", str(timedesc_ids))
    
    # execute the query: **this takes a pretty long time**
    df = pgquery(RESPONSE_TIME_QUERY)
    
   
    return df

# %%
d = {3: 'Dispatched', 5 : 'On Scene', 9: 'Depart Scene', 12: 'Clear'}
table2 = getTimeDataset2(d)
# Out:
# SQL QUERY =
#
#                         SELECT  R.responderunit_id,
#                                 T.timedesc_id, S.description as Station, A.description as Agency,
#                                 RU.description as Responder,
#                                 T.realtime
#                         FROM incident as I
#                         INNER JOIN inctimes as T
#                                 ON I.incident_id = T.incident_id
#                         INNER JOIN responder as R
#                                 ON ( I.incident_id = R.incident_id AND T.responder_id = R.responder_id)
#                         INNER JOIN responderunit as RU
#                                 ON R.responderunit_id = RU.responderunit_id
#                         LEFT JOIN station as S
#                                 ON RU.station_id= S.station_id
#                         LEFT JOIN agency as A
#                                 ON RU.agency_id = A.agency_id
#                         WHERE T.timedesc_id IN (9, 3, 12, 5)
#                                 AND T.responder_id IS NOT NULL
#                                 AND I.incident_id = 1281359
#                                 AND CAST(T.realtime AS DATE) = date '2016-10-19'
#                         ORDER BY T.realtime
#                                 ASC;

# %%
len(table2)
# Out:
# 193

# %%
table2.head(193)
# Out:
#      responderunit_id  timedesc_id                 station agency responder  \
# 0                 122            3                      03   None       T03
# 1                  15            3                     C04   None       C04
# 2                  35            3                      15   None       E15
# 3                  52            3                      03   None       E03
# 4                  64            3                      06   None       E06
# 5                 122            5                      03   None       T03
# 6                  52            5                      03   None       E03
# 7                  35            5                      15   None       E15
# 8                  64            5                      06   None       E06
# 9                   7            3                     C01   None       C01
# 10                 15            5                     C04   None       C04
# 11                  7            5                     C01   None       C01
# 12                 56            3                      04   None       E04
# 13               1602            3                      05   None      RHB5
# 14                123            3                      04   None       T04
# 15                101            3                     PIO   None    PIO351
# 16                 12            3                     C02   None       C02
# 17                 33            3                      13   None       E13
# 18                 45            3                      24   None       E24
# 19                  9            3                    C103   None      C103
# 20                209            3                    None   None      M309
# 21                238            3                    None   None      M338
# 22                210            3                    None   None      M310
# 23                213            3                    None   None      M313
# 24                233            3                    None   None      M333
# 25                 13            3                     C03   None       C03
# 26                304            3                      21   None       E21
# 27                404            3                      16   None       E16
# 28                506            3                      27   None       E27
# 29                550            3                      10   None       T10
# ..                ...          ...                     ...    ...       ...
# 163                64           12                      06   None       E06
# 164                79           12                      09   None       E09
# 165               404           12                      16   None       E16
# 166               140            3                    None   None      TIPF
# 167               148            3                      30   None      E30R
# 168               148            5                      30   None      E30R
# 169                33           12                      13   None       E13
# 170               428           12                      12   None       E12
# 171                12           12                     C02   None       C02
# 172                38           12                      19   None       E19
# 173               556           12                   HC458   None     HC458
# 174                30            5                      01   None       E01
# 175                30            3                      01   None       E01
# 176                30           12                      01   None       E01
# 177               425           12                    C500   None      C500
# 178               117           12                      13   None       T13
# 179                93           12  INVESTIGATOR/INSPECTOR   None      I376
# 180                 8           12                    C102   None      C102
# 181               531           12                      01   None     USAR1
# 182               388           12  INVESTIGATOR/INSPECTOR   None      I377
# 183              1591           12                      17   None      E17R
# 52               2016-10-19 19:30:46       00:03:48      10:18:46
# 56               2016-10-19 12:19:27       00:04:10      02:35:44
# 62               2016-10-19 19:58:53       00:11:45      10:02:57
# 64               2016-10-19 15:16:36       00:07:32      06:00:52
# 79               2016-10-19 15:17:29       00:36:13      04:21:37
# 89               2016-10-19 22:07:44       02:51:24      09:11:06
# 93               2016-10-19 18:15:53       00:00:03      08:26:56
# 101                              NaT       00:16:59           NaT

# %%
Mean_response_time = stationTable['Response_Time'].mean()
Mean_response_time
# Out:
# Timedelta('0 days 00:17:22.322580')

# %%
Median_response_time = stationTable['Response_Time'].median()
Median_response_time
# Out:
# Timedelta('0 days 00:08:35')

# %%
Mean_onscene_time = stationTable['OnScene_Time'].mean()
Mean_onscene_time
# Out:
# Timedelta('0 days 04:39:36.283018')

# %%
Median_onscene_time = stationTable['OnScene_Time'].median()
Median_onscene_time
# Out:
# Timedelta('0 days 03:59:35')

# %% [markdown]
# ## Discussion
# *It turns out this incident is not a good example to show how a tipical incident's response time and onscene time would be, because it has investigators and other weird station codes. But it is a good candidate to show the full spectrum of responders.*
#
# *I have done an analysis on the other incidents happened in the same day to show a tipical incident's response time and onscene time, which is showed below.*

# %%
## Check out metrics for other incidents happened in the very day
def getTimeDataset3(timedesc_dict):
    RESPONSE_TIME_QUERY='''
                        
                        SELECT  I.incident_id,R.responderunit_id,
                                T.timedesc_id, S.description as Station, A.description as Agency,
                                RU.description as Responder,
                                T.realtime
                        FROM incident as I
                        INNER JOIN inctimes as T
                                ON I.incident_id = T.incident_id
                        INNER JOIN responder as R
                                ON ( I.incident_id = R.incident_id AND T.responder_id = R.responder_id)
                        INNER JOIN responderunit as RU
                                ON R.responderunit_id = RU.responderunit_id
                        LEFT JOIN station as S
                                ON RU.station_id= S.station_id
                        LEFT JOIN agency as A
                                ON RU.agency_id = A.agency_id
                        WHERE T.timedesc_id IN ??TIMEDESC_IDS??
                                AND T.responder_id IS NOT NULL
                                AND I.incident_id != 1281359
                                AND CAST(T.realtime AS DATE) = date '2016-10-19'
                        ORDER BY I.incident_id
                                ASC;
                        '''
    
    # add the timedesc_ids that we want to the query
    timedesc_ids = str(tuple(timedesc_dict.keys())).replace("'", "")
    RESPONSE_TIME_QUERY = RESPONSE_TIME_QUERY.replace("??TIMEDESC_IDS??", str(timedesc_ids))
    
    # execute the query: **this takes a pretty long time**
    df = pgquery(RESPONSE_TIME_QUERY)
    
   
    return df

# %%
table3 = getTimeDataset3(d)
# Out:
# SQL QUERY =
#
#                         SELECT  I.incident_id,R.responderunit_id,
#                                 T.timedesc_id, S.description as Station, A.description as Agency,
#                                 RU.description as Responder,
#                                 T.realtime
#                         FROM incident as I
#                         INNER JOIN inctimes as T
#                                 ON I.incident_id = T.incident_id
#                         INNER JOIN responder as R
#                                 ON ( I.incident_id = R.incident_id AND T.responder_id = R.responder_id)
#                         INNER JOIN responderunit as RU
#                                 ON R.responderunit_id = RU.responderunit_id
#                         LEFT JOIN station as S
#                                 ON RU.station_id= S.station_id
#                         LEFT JOIN agency as A
#                                 ON RU.agency_id = A.agency_id
#                         WHERE T.timedesc_id IN (9, 3, 12, 5)
#                                 AND T.responder_id IS NOT NULL
#                                 AND I.incident_id != 1281359
#                                 AND CAST(T.realtime AS DATE) = date '2016-10-19'
#                         ORDER BY I.incident_id
#                                 ASC;

# %%
len(table3)
# Out:
# 1623

# %%
table3.head(50)
# Out:
#     incident_id  responderunit_id  timedesc_id station agency responder  \
# 0       1281269               242           12    None   None      M342
# 1       1281272               224           12    None   None      M324
# 2       1281274               221            9    None   None      M321
# 3       1281274               221           12    None   None      M321
# 4       1281276                42           12      22   None       E22
# 5       1281277               227            9    None   None      M327
# 6       1281277               227           12    None   None      M327
# 7       1281278                61            3      31   None       E31
# 8       1281278               234            3    None   None      M334
# 9       1281278               234            5    None   None      M334
# 10      1281278               234            9    None   None      M334
# 11      1281278                61           12      31   None       E31
# 12      1281278               234           12    None   None      M334
# 13      1281279               222            9    None   None      M322
# 14      1281279                33           12      13   None       E13
# 15      1281279               222           12    None   None      M322
# 16      1281280               114            3      01   None       S01
# 17      1281280               243            3    None   None      M343
# 18      1281280               114            5      01   None       S01
# 19      1281280               243            5    None   None      M343
# 20      1281280               243            9    None   None      M343
# 21      1281280               114           12      01   None       S01
# 22      1281280               243           12    None   None      M343
# 23      1281281                37            3      18   None       E18
# 24      1281281               219            3    None   None      M319
# 25      1281281               219            5    None   None      M319
# 26      1281281               219            9    None   None      M319
# 27      1281281                37           12      18   None       E18
# 28      1281281               219           12    None   None      M319
# 29      1281282               223            3    None   None      M323
# 30      1281282               428            3      12   None       E12
# 31      1281282               223            5    None   None      M323
# 32      1281282               428            5      12   None       E12
# 33      1281282               223            9    None   None      M323
# 34      1281282               223           12    None   None      M323
# 35      1281282               428           12      12   None       E12
# 36      1281283              1597            3      24   None       R24
# 37      1281283              1597            5      24   None       R24
# 38      1281283              1597           12      24   None       R24
# 39      1281284               123            3      04   None       T04
# 40      1281284               224            3    None   None      M324
# 41      1281284               224            5    None   None      M324
# 42      1281284               224            9    None   None      M324
# 43      1281284               123           12      04   None       T04
# 44      1281284               224           12    None   None      M324
# 45      1281285                30            3      01   None       E01
# 46      1281285               117            3      13   None       T13
# 47      1281285               117            5      13   None       T13
# 48      1281285                30           12      01   None       E01
# 49      1281285               117           12      13   None       T13
#
#               realtime
# 0  2016-10-19 00:26:08
# 1  2016-10-19 00:29:25
# 2  2016-10-19 00:07:01
# 3  2016-10-19 00:43:35
# 4  2016-10-19 00:30:10
# 5  2016-10-19 00:03:29
# 6  2016-10-19 00:42:56
# 7  2016-10-19 00:03:22
# 8  2016-10-19 00:03:22
# 9  2016-10-19 00:06:44
# 10 2016-10-19 00:21:58
# 11 2016-10-19 00:08:46
# 12 2016-10-19 01:00:11
# 13 2016-10-19 00:22:31
# 14 2016-10-19 00:07:57
# 15 2016-10-19 01:05:26
# 16 2016-10-19 00:00:43
# 17 2016-10-19 00:00:43
# 18 2016-10-19 00:06:22
# 19 2016-10-19 00:04:53
# 1281284     123              2016-10-19 00:46:13                 NaT
#             224              2016-10-19 00:46:13 2016-10-19 00:51:04
# 1281285     30               2016-10-19 00:46:45                 NaT
#             117              2016-10-19 00:46:45 2016-10-19 00:52:45
# 1281290     478              2016-10-19 00:48:36 2016-10-19 00:56:08
# 1281287     234              2016-10-19 01:01:12 2016-10-19 01:05:01
#             60               2016-10-19 01:01:12                 NaT
# 1281288     59               2016-10-19 01:07:34 2016-10-19 01:14:28
#             240              2016-10-19 01:07:34 2016-10-19 01:13:50
# 1281289     61               2016-10-19 01:13:06                 NaT
#
# timedesc_id                         Depart Scene               Clear  \
# incident_id responderunit_id
# 1281280     114                              NaT 2016-10-19 00:11:41
#             243              2016-10-19 00:23:09 2016-10-19 00:57:09
# 1281278     61                               NaT 2016-10-19 00:08:46
#             234              2016-10-19 00:21:58 2016-10-19 01:00:11
# 1281281     37                               NaT 2016-10-19 00:21:36
#             219              2016-10-19 00:27:22 2016-10-19 01:10:31
# 1281282     223              2016-10-19 01:01:55 2016-10-19 01:36:41
#             428                              NaT 2016-10-19 00:34:17
# 1281283     1597                             NaT 2016-10-19 00:43:07
# 1281286     33                               NaT 2016-10-19 00:55:49
# 1281284     123                              NaT 2016-10-19 00:51:20
#             224              2016-10-19 00:57:46 2016-10-19 01:34:20
# 1281285     30                               NaT 2016-10-19 00:50:12
#             117                              NaT 2016-10-19 01:27:53
# 1281290     478                              NaT 2016-10-19 01:23:43
# 1281287     234                              NaT 2016-10-19 01:15:34
#             60                               NaT 2016-10-19 01:09:47
# 1281288     59                               NaT 2016-10-19 01:16:35
#             240              2016-10-19 01:33:40 2016-10-19 02:17:18
# 1281289     61                               NaT 2016-10-19 01:18:53
#
# timedesc_id                   Response_Time  OnScene_Time
# incident_id responderunit_id
# 1281280     114                    00:05:39      00:05:19
#             243                    00:04:10      00:52:16
# 1281278     61                          NaT           NaT
#             234                    00:03:22      00:53:27
# 1281281     37                          NaT           NaT
#             219                    00:02:41      00:49:48
# 1281282     223                    00:05:51      01:04:20
#             428                    00:07:07      00:00:40
# 1281283     1597                   00:09:12      00:03:58
# 1281286     33                     00:07:26      00:05:13
# 1281284     123                         NaT           NaT
#             224                    00:04:51      00:43:16
# 1281285     30                          NaT           NaT
#             117                    00:06:00      00:35:08
# 1281290     478                    00:07:32      00:27:35
# 1281287     234                    00:03:49      00:10:33
#             60                          NaT           NaT
# 1281288     59                     00:06:54      00:02:07
#             240                    00:06:16      01:03:28
# 1281289     61                          NaT           NaT

# %%
Mean_response_time_other = table3['Response_Time'].mean()
Mean_response_time_other
# Out:
# Timedelta('0 days 00:05:50.139534')

# %%
Median_response_time_other = table3['Response_Time'].median()
Median_response_time_other
# Out:
# Timedelta('0 days 00:05:19')

# %%
Mean_onscene_time_other = table3['OnScene_Time'].mean()
Mean_onscene_time_other
# Out:
# Timedelta('0 days 00:26:25.393719')

# %%
Median_onscene_time_other = table3['OnScene_Time'].median()
Median_onscene_time_other
# Out:
# Timedelta('0 days 00:12:31')
